# %% [markdown]
# PROJECT OF Lung Cancer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/Lung Cancer Dataset.csv')
df=pd.DataFrame(data)

# %%
#to finding the first five data
df.head(5)
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country salary
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
#to find the last five data
df.tail(5)
# Out:
#       AGE  GENDER  SMOKING  FINGER_DISCOLORATION  MENTAL_STRESS  \
# 4995   32       0        1                     1              0
# 4996   80       0        1                     1              1
# 4997   51       1        0                     0              1
# 4998   76       1        0                     1              0
# 4999   33       0        1                     0              0
#
#       EXPOSURE_TO_POLLUTION  LONG_TERM_ILLNESS  ENERGY_LEVEL  IMMUNE_WEAKNESS  \
# 4995                      0                  1     60.700696                1
# 4996                      1                  1     50.751741                0
# 4997                      0                  0     61.063496                1
# 4998                      0                  0     48.662872                0
# 4999                      1                  1     58.245188                0
#
#       BREATHING_ISSUE  ALCOHOL_CONSUMPTION  THROAT_DISCOMFORT  \
# 4995                1                    1                  1
# 4996                1                    1                  1
# 4997                0                    0                  0
# 4998                1                    0                  1
# 4999                1                    1                  1
#
#       OXYGEN_SATURATION  CHEST_TIGHTNESS  FAMILY_HISTORY  \
# 4995          94.012495                0               1
# 4996          94.394968                0               0
# 4997          98.108901                0               0
# 4998          95.577773                1               0
# 4999          94.206934                1               0
#
#       SMOKING_FAMILY_HISTORY  STRESS_IMMUNE PULMONARY_DISEASE
# 4995                       1              0               YES
# 4996                       0              0               YES
# 4997                       0              1                NO
# 4998                       0              0                NO
# 4999                       0              0                NO

# %%
#to get the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AGE                     5000 non-null   int64
#  1   GENDER                  5000 non-null   int64
#  2   SMOKING                 5000 non-null   int64
#  3   FINGER_DISCOLORATION    5000 non-null   int64
#  4   MENTAL_STRESS           5000 non-null   int64
#  5   EXPOSURE_TO_POLLUTION   5000 non-null   int64
#  6   LONG_TERM_ILLNESS       5000 non-null   int64
#  7   ENERGY_LEVEL            5000 non-null   float64
#  8   IMMUNE_WEAKNESS         5000 non-null   int64
#  9   BREATHING_ISSUE         5000 non-null   int64
#  10  ALCOHOL_CONSUMPTION     5000 non-null   int64
#  11  THROAT_DISCOMFORT       5000 non-null   int64
#  12  OXYGEN_SATURATION       5000 non-null   float64
#  13  CHEST_TIGHTNESS         5000 non-null   int64
#  14  FAMILY_HISTORY          5000 non-null   int64
#  15  SMOKING_FAMILY_HISTORY  5000 non-null   int64
#  16  STRESS_IMMUNE           5000 non-null   int64
#  17  PULMONARY_DISEASE       5000 non-null   object
# dtypes: float64(2), int64(15), object(1)
# memory usage: 703.3+ KB

# %%
#to generate the summary of statistics of DataFrame
df.describe()
# Out:
#                AGE       GENDER      SMOKING  FINGER_DISCOLORATION  \
# count  5000.000000  5000.000000  5000.000000             5000.0000
# mean     57.222800     0.501200     0.666400                0.6012
# std      15.799224     0.500049     0.471546                0.4897
# min      30.000000     0.000000     0.000000                0.0000
# 25%      44.000000     0.000000     0.000000                0.0000
# 50%      57.000000     1.000000     1.000000                1.0000
# 75%      71.000000     1.000000     1.000000                1.0000
# max      84.000000     1.000000     1.000000                1.0000
#
#        MENTAL_STRESS  EXPOSURE_TO_POLLUTION  LONG_TERM_ILLNESS  ENERGY_LEVEL  \
# count    5000.000000            5000.000000        5000.000000   5000.000000
# mean        0.539800               0.516000           0.439200     55.032043
# std         0.498463               0.499794           0.496339      7.913083
# min         0.000000               0.000000           0.000000     23.258308
# 25%         0.000000               0.000000           0.000000     49.440685
# 50%         1.000000               1.000000           0.000000     55.050421
# 75%         1.000000               1.000000           1.000000     60.323320
# max         1.000000               1.000000           1.000000     83.046971
#
#        IMMUNE_WEAKNESS  BREATHING_ISSUE  ALCOHOL_CONSUMPTION  \
# count      5000.000000       5000.00000          5000.000000
# mean          0.394800          0.80040             0.354200
# std           0.488857          0.39974             0.478318
# min           0.000000          0.00000             0.000000
# 25%           0.000000          1.00000             0.000000
# 50%           0.000000          1.00000             0.000000
# 75%           1.000000          1.00000             1.000000
# max           1.000000          1.00000             1.000000
#
#        THROAT_DISCOMFORT  OXYGEN_SATURATION  CHEST_TIGHTNESS  FAMILY_HISTORY  \
# count        5000.000000        5000.000000      5000.000000     5000.000000
# mean            0.698200          94.991029         0.600600        0.301800
# std             0.459085           1.481048         0.489824        0.459085
# min             0.000000          89.923133         0.000000        0.000000
# 25%             0.000000          93.973176         0.000000        0.000000
# 50%             1.000000          94.974073         1.000000        0.000000
# 75%             1.000000          95.989272         1.000000        1.000000
# max             1.000000          99.795786         1.000000        1.000000
#
#        SMOKING_FAMILY_HISTORY  STRESS_IMMUNE
# count             5000.000000    5000.000000
# mean                 0.204000       0.209600
# std                  0.403009       0.407064
# min                  0.000000       0.000000
# 25%                  0.000000       0.000000
# 50%                  0.000000       0.000000
# 75%                  0.000000       0.000000
# max                  1.000000       1.000000

# %%
#to find the missing value of the dataframe
df.isnull().sum()
# Out:
# AGE                       0
# GENDER                    0
# SMOKING                   0
# FINGER_DISCOLORATION      0
# MENTAL_STRESS             0
# EXPOSURE_TO_POLLUTION     0
# LONG_TERM_ILLNESS         0
# ENERGY_LEVEL              0
# IMMUNE_WEAKNESS           0
# BREATHING_ISSUE           0
# ALCOHOL_CONSUMPTION       0
# THROAT_DISCOMFORT         0
# OXYGEN_SATURATION         0
# CHEST_TIGHTNESS           0
# FAMILY_HISTORY            0
# SMOKING_FAMILY_HISTORY    0
# STRESS_IMMUNE             0
# PULMONARY_DISEASE         0
# dtype: int64

# %%
#to drop the missing values
df.dropna()
# Out:
#       AGE  GENDER  SMOKING  FINGER_DISCOLORATION  MENTAL_STRESS  \
# 0      68       1        1                     1              1
# 1      81       1        1                     0              0
# 2      58       1        1                     0              0
# 3      44       0        1                     0              1
# 4      72       0        1                     1              1
# ...   ...     ...      ...                   ...            ...
# 4995   32       0        1                     1              0
# 4996   80       0        1                     1              1
# 4997   51       1        0                     0              1
# 4998   76       1        0                     1              0
# 4999   33       0        1                     0              0
#
#       EXPOSURE_TO_POLLUTION  LONG_TERM_ILLNESS  ENERGY_LEVEL  IMMUNE_WEAKNESS  \
# 0                         1                  0     57.831178                0
# 1                         1                  1     47.694835                1
# 2                         0                  0     59.577435                0
# 3                         1                  0     59.785767                0
# 4                         1                  1     59.733941                0
# ...                     ...                ...           ...              ...
# 4995                      0                  1     60.700696                1
# 4996                      1                  1     50.751741                0
# 4997                      0                  0     61.063496                1
# 4998                      0                  0     48.662872                0
# 4999                      1                  1     58.245188                0
#
#       BREATHING_ISSUE  ALCOHOL_CONSUMPTION  THROAT_DISCOMFORT  \
# 0                   0                    1                  1
# 1                   1                    0                  1
# 2                   1                    1                  0
# 3                   1                    0                  1
# 4                   1                    0                  1
# ...               ...                  ...                ...
# 4995                1                    1                  1
# 4996                1                    1                  1
# 4997                0                    0                  0
# 4998                1                    0                  1
# 4999                1                    1                  1
#
#       OXYGEN_SATURATION  CHEST_TIGHTNESS  FAMILY_HISTORY  \
# 0             95.977287                1               0
# 1             97.184483                0               0
# 2             94.974939                0               0
# 3             95.187900                0               0
# 4             93.503008                0               0
# ...                 ...              ...             ...
# 4995          94.012495                0               1
# 4996          94.394968                0               0
# 4997          98.108901                0               0
# 4998          95.577773                1               0
# 4999          94.206934                1               0
#
#       SMOKING_FAMILY_HISTORY  STRESS_IMMUNE PULMONARY_DISEASE
# 0                          0              0                NO
# 1                          0              0               YES
# 2                          0              0                NO
# 3                          0              0               YES
# 4                          0              0               YES
# ...                      ...            ...               ...
# 4995                       1              0               YES
# 4996                       0              0               YES
# 4997                       0              1                NO
# 4998                       0              0                NO
# 4999                       0              0                NO
#
# [5000 rows x 18 columns]

# %%
#to handle duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#to remove duplicates
df=df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# AGE                       0
# GENDER                    0
# SMOKING                   0
# FINGER_DISCOLORATION      0
# MENTAL_STRESS             0
# EXPOSURE_TO_POLLUTION     0
# LONG_TERM_ILLNESS         0
# ENERGY_LEVEL              0
# IMMUNE_WEAKNESS           0
# BREATHING_ISSUE           0
# ALCOHOL_CONSUMPTION       0
# THROAT_DISCOMFORT         0
# OXYGEN_SATURATION         0
# CHEST_TIGHTNESS           0
# FAMILY_HISTORY            0
# SMOKING_FAMILY_HISTORY    0
# STRESS_IMMUNE             0
# PULMONARY_DISEASE         0
# dtype: int64

# %%
y=df['ENERGY_LEVEL']
y
# Out:
# 0       57.831178
# 1       47.694835
# 2       59.577435
# 3       59.785767
# 4       59.733941
#           ...
# 4995    60.700696
# 4996    50.751741
# 4997    61.063496
# 4998    48.662872
# 4999    58.245188
# Name: ENERGY_LEVEL, Length: 5000, dtype: float64

# %%
x=df.drop('ENERGY_LEVEL',axis=1)

# %%
x.columns
# Out:
# Index(['AGE', 'GENDER', 'SMOKING', 'FINGER_DISCOLORATION', 'MENTAL_STRESS',
#        'EXPOSURE_TO_POLLUTION', 'LONG_TERM_ILLNESS', 'IMMUNE_WEAKNESS',
#        'BREATHING_ISSUE', 'ALCOHOL_CONSUMPTION', 'THROAT_DISCOMFORT',
#        'OXYGEN_SATURATION', 'CHEST_TIGHTNESS', 'FAMILY_HISTORY',
#        'SMOKING_FAMILY_HISTORY', 'STRESS_IMMUNE', 'PULMONARY_DISEASE'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
categorical_columns=df.select_dtypes(include=['object']).columns.tolist()
categorical_columns
# Out:
# ['PULMONARY_DISEASE']

# %%
df_pandas_encoded=pd.get_dummies(df,columns=['PULMONARY_DISEASE'],drop_first=True)

# %%
encoder=OneHotEncoder(sparse_output=False)
categorical_columns=df.select_dtypes(include=['object']).columns.tolist()

# %%
df_encoded=pd.DataFrame(encoder.fit_transform(df[categorical_columns]))

# %%
one_hot_encoded_data=encoder.fit_transform(df[categorical_columns])

one_hot_encoded_df=pd.DataFrame(one_hot_encoded_data,columns=encoder.get_feature_names_out(categorical_columns))
df_sklearn_encoded=pd.concat([df.drop(categorical_columns,axis=1),one_hot_encoded_df],axis=1)

# %%
df1= df_sklearn_encoded

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AGE                     5000 non-null   int64
#  1   GENDER                  5000 non-null   int64
#  2   SMOKING                 5000 non-null   int64
#  3   FINGER_DISCOLORATION    5000 non-null   int64
#  4   MENTAL_STRESS           5000 non-null   int64
#  5   EXPOSURE_TO_POLLUTION   5000 non-null   int64
#  6   LONG_TERM_ILLNESS       5000 non-null   int64
#  7   ENERGY_LEVEL            5000 non-null   float64
#  8   IMMUNE_WEAKNESS         5000 non-null   int64
#  9   BREATHING_ISSUE         5000 non-null   int64
#  10  ALCOHOL_CONSUMPTION     5000 non-null   int64
#  11  THROAT_DISCOMFORT       5000 non-null   int64
#  12  OXYGEN_SATURATION       5000 non-null   float64
#  13  CHEST_TIGHTNESS         5000 non-null   int64
#  14  FAMILY_HISTORY          5000 non-null   int64
#  15  SMOKING_FAMILY_HISTORY  5000 non-null   int64
#  16  STRESS_IMMUNE           5000 non-null   int64
#  17  PULMONARY_DISEASE_NO    5000 non-null   float64
#  18  PULMONARY_DISEASE_YES   5000 non-null   float64
# dtypes: float64(4), int64(15)
# memory usage: 742.3 KB

# %%
df.isna().sum()
# Out:
# AGE                       0
# GENDER                    0
# SMOKING                   0
# FINGER_DISCOLORATION      0
# MENTAL_STRESS             0
# EXPOSURE_TO_POLLUTION     0
# LONG_TERM_ILLNESS         0
# ENERGY_LEVEL              0
# IMMUNE_WEAKNESS           0
# BREATHING_ISSUE           0
# ALCOHOL_CONSUMPTION       0
# THROAT_DISCOMFORT         0
# OXYGEN_SATURATION         0
# CHEST_TIGHTNESS           0
# FAMILY_HISTORY            0
# SMOKING_FAMILY_HISTORY    0
# STRESS_IMMUNE             0
# PULMONARY_DISEASE         0
# dtype: int64

# %%
df=df.dropna

# %%
df1.shape
# Out:
# (5000, 19)

# %%
num_columns=df1.select_dtypes(include=['int64','float64'])
num_columns
# Out:
#       AGE  GENDER  SMOKING  FINGER_DISCOLORATION  MENTAL_STRESS  \
# 0      68       1        1                     1              1
# 1      81       1        1                     0              0
# 2      58       1        1                     0              0
# 3      44       0        1                     0              1
# 4      72       0        1                     1              1
# ...   ...     ...      ...                   ...            ...
# 4995   32       0        1                     1              0
# 4996   80       0        1                     1              1
# 4997   51       1        0                     0              1
# 4998   76       1        0                     1              0
# 4999   33       0        1                     0              0
#
#       EXPOSURE_TO_POLLUTION  LONG_TERM_ILLNESS  ENERGY_LEVEL  IMMUNE_WEAKNESS  \
# 0                         1                  0     57.831178                0
# 1                         1                  1     47.694835                1
# 2                         0                  0     59.577435                0
# 3                         1                  0     59.785767                0
# 4                         1                  1     59.733941                0
# ...                     ...                ...           ...              ...
# 4995                      0                  1     60.700696                1
# 4996                      1                  1     50.751741                0
# 4997                      0                  0     61.063496                1
# 4998                      0                  0     48.662872                0
# 4999                      1                  1     58.245188                0
#
#       BREATHING_ISSUE  ALCOHOL_CONSUMPTION  THROAT_DISCOMFORT  \
# 0                   0                    1                  1
# 1                   1                    0                  1
# 2                   1                    1                  0
# 3                   1                    0                  1
# 4                   1                    0                  1
# ...               ...                  ...                ...
# 4995                1                    1                  1
# 4996                1                    1                  1
# 4997                0                    0                  0
# 4998                1                    0                  1
# 4999                1                    1                  1
#
#       OXYGEN_SATURATION  CHEST_TIGHTNESS  FAMILY_HISTORY  \
# 0             95.977287                1               0
# 1             97.184483                0               0
# 2             94.974939                0               0
# 3             95.187900                0               0
# 4             93.503008                0               0
# ...                 ...              ...             ...
# 4995          94.012495                0               1
# 4996          94.394968                0               0
# 4997          98.108901                0               0
# 4998          95.577773                1               0
# 4999          94.206934                1               0
#
#       SMOKING_FAMILY_HISTORY  STRESS_IMMUNE  PULMONARY_DISEASE_NO  \
# 0                          0              0                   1.0
# 1                          0              0                   0.0
# 2                          0              0                   1.0
# 3                          0              0                   0.0
# 4                          0              0                   0.0
# ...                      ...            ...                   ...
# 4995                       1              0                   0.0
# 4996                       0              0                   0.0
# 4997                       0              1                   1.0
# 4998                       0              0                   1.0
# 4999                       0              0                   1.0
#
#       PULMONARY_DISEASE_YES
# 0                       0.0
# 1                       1.0
# 2                       0.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 4995                    1.0
# 4996                    1.0
# 4997                    0.0
# 4998                    0.0
# 4999                    0.0
#
# [5000 rows x 19 columns]

# %%
df1.isna().sum()
# Out:
# AGE                       0
# GENDER                    0
# SMOKING                   0
# FINGER_DISCOLORATION      0
# MENTAL_STRESS             0
# EXPOSURE_TO_POLLUTION     0
# LONG_TERM_ILLNESS         0
# ENERGY_LEVEL              0
# IMMUNE_WEAKNESS           0
# BREATHING_ISSUE           0
# ALCOHOL_CONSUMPTION       0
# THROAT_DISCOMFORT         0
# OXYGEN_SATURATION         0
# CHEST_TIGHTNESS           0
# FAMILY_HISTORY            0
# SMOKING_FAMILY_HISTORY    0
# STRESS_IMMUNE             0
# PULMONARY_DISEASE_NO      0
# PULMONARY_DISEASE_YES     0
# dtype: int64

# %%
for column in num_columns.columns:
  sns.boxplot(data=num_columns,x=column)
  plt.show()

# %%
def handling_outliers(df1):
  for col in df1.select_dtypes(include=['int64','float64']).columns:
    Q1=df1[col].quantile(0.25)
    Q3=df1[col].quantile(0.75)
    IQR=Q3-Q1
    Lower_bound=Q1-(1.5*IQR)
    Upper_bound=Q3+(1.5*IQR)
    df1[col]=df1[col].apply(lambda x:Lower_bound if x<Lower_bound else (Upper_bound if x>Upper_bound else x))
  return df1

# %%
df2=handling_outliers(df1)
df2.head()
sns.boxplot(df2)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, y='AGE', x='MENTAL_STRESS')
plt.title('MENTAL_STRESS VS AGE')
plt.xlabel('MENTAL_STRESS')
plt.ylabel('AGE')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(data=df, x='IMMUNE_WEAKNESS', y='SMOKING', marker='o')
plt.title('IMMUNE_WEAKNESS VS SMOKING')
plt.xlabel('IMMUNE_WEAKNESS')
plt.ylabel('SMOKING')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df1, x='hours-per-week', bins=20, kde=True, color='skyblue')
plt.title('HOURS PER WEEK')
plt.xlabel('HOURS')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df1, x='ENERGY_LEVEL', fill=True, color='skyblue')
plt.title('LEVEL OF ENERGY')
plt.xlabel('ENERGY_LEVEL')
plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %%
a=df2.corr()
a
# Out:
#                              AGE    GENDER   SMOKING  FINGER_DISCOLORATION  \
# AGE                     1.000000 -0.004262 -0.030163             -0.012559
# GENDER                 -0.004262  1.000000  0.010182             -0.020919
# SMOKING                -0.030163  0.010182  1.000000              0.005892
# FINGER_DISCOLORATION   -0.012559 -0.020919  0.005892              1.000000
# MENTAL_STRESS          -0.027137 -0.014236  0.008839              0.001116
# EXPOSURE_TO_POLLUTION  -0.004834 -0.024890 -0.008753              0.009729
# LONG_TERM_ILLNESS       0.020401  0.017220  0.009048             -0.021592
# ENERGY_LEVEL           -0.007166 -0.007253  0.018523             -0.004530
# IMMUNE_WEAKNESS        -0.023072  0.020156  0.007399              0.000193
# BREATHING_ISSUE              NaN       NaN       NaN                   NaN
# ALCOHOL_CONSUMPTION    -0.001551 -0.015577  0.013131             -0.015992
# THROAT_DISCOMFORT       0.032412 -0.031971 -0.002220              0.017094
# OXYGEN_SATURATION      -0.001353 -0.006517  0.014336              0.011747
# CHEST_TIGHTNESS        -0.005792  0.027683  0.010220              0.000497
# FAMILY_HISTORY          0.024816  0.037199  0.013309             -0.012645
# SMOKING_FAMILY_HISTORY       NaN       NaN       NaN                   NaN
# STRESS_IMMUNE                NaN       NaN       NaN                   NaN
# PULMONARY_DISEASE_NO    0.006489  0.004025 -0.461467             -0.026066
# PULMONARY_DISEASE_YES  -0.006489 -0.004025  0.461467              0.026066
#
#                         MENTAL_STRESS  EXPOSURE_TO_POLLUTION  \
# AGE                         -0.027137              -0.004834
# GENDER                      -0.014236              -0.024890
# SMOKING                      0.008839              -0.008753
# FINGER_DISCOLORATION         0.001116               0.009729
# MENTAL_STRESS                1.000000               0.003466
# EXPOSURE_TO_POLLUTION        0.003466               1.000000
# LONG_TERM_ILLNESS            0.027975              -0.016238
# ENERGY_LEVEL                 0.001397              -0.011872
# IMMUNE_WEAKNESS             -0.014420               0.003616
# BREATHING_ISSUE                   NaN                    NaN
# ALCOHOL_CONSUMPTION         -0.005022               0.005995
# THROAT_DISCOMFORT            0.003985               0.012767
# OXYGEN_SATURATION            0.015006               0.000101
# CHEST_TIGHTNESS              0.005719               0.004455
# FAMILY_HISTORY               0.012624               0.003798
# SMOKING_FAMILY_HISTORY            NaN                    NaN
# STRESS_IMMUNE                     NaN                    NaN
# PULMONARY_DISEASE_NO        -0.089367              -0.095222
# PULMONARY_DISEASE_YES        0.089367               0.095222
#
#                         LONG_TERM_ILLNESS  ENERGY_LEVEL  IMMUNE_WEAKNESS  \
# AGE                              0.020401     -0.007166        -0.023072
# GENDER                           0.017220     -0.007253         0.020156
# SMOKING                          0.009048      0.018523         0.007399
# FINGER_DISCOLORATION            -0.021592     -0.004530         0.000193
# MENTAL_STRESS                    0.027975      0.001397        -0.014420
# EXPOSURE_TO_POLLUTION           -0.016238     -0.011872         0.003616
# LONG_TERM_ILLNESS                1.000000      0.021098         0.000840
# ENERGY_LEVEL                     0.021098      1.000000        -0.006116
# IMMUNE_WEAKNESS                  0.000840     -0.006116         1.000000
# BREATHING_ISSUE                       NaN           NaN              NaN
# ALCOHOL_CONSUMPTION              0.000149      0.002023         0.004970
# THROAT_DISCOMFORT               -0.015141      0.002414        -0.026960
# OXYGEN_SATURATION                0.015702      0.009430         0.005362
# CHEST_TIGHTNESS                  0.003359     -0.006785         0.000347
# FAMILY_HISTORY                   0.007240      0.003505         0.008242
# SMOKING_FAMILY_HISTORY                NaN           NaN              NaN
# STRESS_IMMUNE                         NaN           NaN              NaN
# PULMONARY_DISEASE_NO            -0.012589     -0.171086        -0.124736
# PULMONARY_DISEASE_YES            0.012589      0.171086         0.124736
#
#                         BREATHING_ISSUE  ALCOHOL_CONSUMPTION  \
# AGE                                 NaN            -0.001551
# GENDER                              NaN            -0.015577
# SMOKING                             NaN             0.013131
# FINGER_DISCOLORATION                NaN            -0.015992
# MENTAL_STRESS                       NaN            -0.005022
# EXPOSURE_TO_POLLUTION               NaN             0.005995
# LONG_TERM_ILLNESS                   NaN             0.000149
# ENERGY_LEVEL                        NaN             0.002023
# IMMUNE_WEAKNESS                     NaN             0.004970
# BREATHING_ISSUE                     NaN                  NaN
# ALCOHOL_CONSUMPTION                 NaN             1.000000
# THROAT_DISCOMFORT                   NaN            -0.005932
# OXYGEN_SATURATION                   NaN             0.020586
# CHEST_TIGHTNESS                     NaN            -0.008250
# FAMILY_HISTORY                      NaN            -0.009554
# SMOKING_FAMILY_HISTORY              NaN                  NaN
# STRESS_IMMUNE                       NaN                  NaN
# PULMONARY_DISEASE_NO                NaN            -0.000421
# PULMONARY_DISEASE_YES               NaN             0.000421
#
#                         THROAT_DISCOMFORT  OXYGEN_SATURATION  CHEST_TIGHTNESS  \
# AGE                              0.032412          -0.001353        -0.005792
# GENDER                          -0.031971          -0.006517         0.027683
# SMOKING                         -0.002220           0.014336         0.010220
# FINGER_DISCOLORATION             0.017094           0.011747         0.000497
# MENTAL_STRESS                    0.003985           0.015006         0.005719
# EXPOSURE_TO_POLLUTION            0.012767           0.000101         0.004455
# LONG_TERM_ILLNESS               -0.015141           0.015702         0.003359
# ENERGY_LEVEL                     0.002414           0.009430        -0.006785
# IMMUNE_WEAKNESS                 -0.026960           0.005362         0.000347
# BREATHING_ISSUE                       NaN                NaN              NaN
# ALCOHOL_CONSUMPTION             -0.005932           0.020586        -0.008250
# THROAT_DISCOMFORT                1.000000           0.009915        -0.001507
# OXYGEN_SATURATION                0.009915           1.000000         0.019113
# CHEST_TIGHTNESS                 -0.001507           0.019113         1.000000
# FAMILY_HISTORY                  -0.012893           0.012188        -0.001161
# SMOKING_FAMILY_HISTORY                NaN                NaN              NaN
# STRESS_IMMUNE                         NaN                NaN              NaN
# PULMONARY_DISEASE_NO            -0.283545          -0.018590        -0.026244
# PULMONARY_DISEASE_YES            0.283545           0.018590         0.026244
#
#                         FAMILY_HISTORY  SMOKING_FAMILY_HISTORY  STRESS_IMMUNE  \
# AGE                           0.024816                     NaN            NaN
# GENDER                        0.037199                     NaN            NaN
# SMOKING                       0.013309                     NaN            NaN
# FINGER_DISCOLORATION         -0.012645                     NaN            NaN
# MENTAL_STRESS                 0.012624                     NaN            NaN
# EXPOSURE_TO_POLLUTION         0.003798                     NaN            NaN
# LONG_TERM_ILLNESS             0.007240                     NaN            NaN
# ENERGY_LEVEL                  0.003505                     NaN            NaN
# IMMUNE_WEAKNESS               0.008242                     NaN            NaN
# BREATHING_ISSUE                    NaN                     NaN            NaN
# ALCOHOL_CONSUMPTION          -0.009554                     NaN            NaN
# THROAT_DISCOMFORT            -0.012893                     NaN            NaN
# OXYGEN_SATURATION             0.012188                     NaN            NaN
# CHEST_TIGHTNESS              -0.001161                     NaN            NaN
# FAMILY_HISTORY                1.000000                     NaN            NaN
# SMOKING_FAMILY_HISTORY             NaN                     NaN            NaN
# STRESS_IMMUNE                      NaN                     NaN            NaN
# PULMONARY_DISEASE_NO         -0.117255                     NaN            NaN
# PULMONARY_DISEASE_YES         0.117255                     NaN            NaN
#
#                         PULMONARY_DISEASE_NO  PULMONARY_DISEASE_YES
# AGE                                 0.006489              -0.006489
# GENDER                              0.004025              -0.004025
# SMOKING                            -0.461467               0.461467
# FINGER_DISCOLORATION               -0.026066               0.026066
# MENTAL_STRESS                      -0.089367               0.089367
# EXPOSURE_TO_POLLUTION              -0.095222               0.095222
# LONG_TERM_ILLNESS                  -0.012589               0.012589
# ENERGY_LEVEL                       -0.171086               0.171086
# IMMUNE_WEAKNESS                    -0.124736               0.124736
# BREATHING_ISSUE                          NaN                    NaN
# ALCOHOL_CONSUMPTION                -0.000421               0.000421
# THROAT_DISCOMFORT                  -0.283545               0.283545
# OXYGEN_SATURATION                  -0.018590               0.018590
# CHEST_TIGHTNESS                    -0.026244               0.026244
# FAMILY_HISTORY                     -0.117255               0.117255
# SMOKING_FAMILY_HISTORY                   NaN                    NaN
# STRESS_IMMUNE                            NaN                    NaN
# PULMONARY_DISEASE_NO                1.000000              -1.000000
# PULMONARY_DISEASE_YES              -1.000000               1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(a,cmap='coolwarm',linewidth=0.5,fmt='.2f')
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
#violin plot
plt.figure(figsize=(8,6))
sns.violinplot(x='FAMILY_HISTORY',y='BREATHING_ISSUE',data=df)
plt.title('FAMILY_HISTORY VS BREATHING_ISSUE')
plt.xlabel('FAMILY HISTORY')
plt.ylabel('BREATHING_ISSUE')
plt.tight_layout()
plt.show()

# %%
df1.skew()
# Out:
# AGE                      -0.018267
# GENDER                   -0.004801
# SMOKING                  -0.706046
# FINGER_DISCOLORATION     -0.413479
# MENTAL_STRESS            -0.159755
# EXPOSURE_TO_POLLUTION    -0.064052
# LONG_TERM_ILLNESS         0.245092
# ENERGY_LEVEL              0.024833
# IMMUNE_WEAKNESS           0.430564
# BREATHING_ISSUE           0.000000
# ALCOHOL_CONSUMPTION       0.609880
# THROAT_DISCOMFORT        -0.863802
# OXYGEN_SATURATION         0.022011
# CHEST_TIGHTNESS          -0.410924
# FAMILY_HISTORY            0.863802
# SMOKING_FAMILY_HISTORY    0.000000
# STRESS_IMMUNE             0.000000
# PULMONARY_DISEASE_NO     -0.377034
# PULMONARY_DISEASE_YES     0.377034
# dtype: float64

# %%
X=df1.drop(columns='ENERGY_LEVEL',axis=1)
y=df1['ENERGY_LEVEL']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
selecter=SelectKBest(score_func=f_regression,k=70)
X_new=selecter.fit_transform(X,y)
Selected_features=X.columns[selecter.get_support()]
feature_score=pd.DataFrame({'Feature':X.columns,'Score':selecter.scores_}).sort_values(by='Score',ascending=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=70 is greater than n_features=18. All the features will be returned.
#   warnings.warn(

# %%
print(feature_score)
# Out:
#                    Feature       Score
# 17   PULMONARY_DISEASE_YES  150.704525
# 16    PULMONARY_DISEASE_NO  150.704525
# 6        LONG_TERM_ILLNESS    2.225671
# 2                  SMOKING    1.715347
# 5    EXPOSURE_TO_POLLUTION    0.704580
# 11       OXYGEN_SATURATION    0.444476
# 1                   GENDER    0.262943
# 0                      AGE    0.256683
# 12         CHEST_TIGHTNESS    0.230087
# 7          IMMUNE_WEAKNESS    0.186980
# 3     FINGER_DISCOLORATION    0.102554
# 13          FAMILY_HISTORY    0.061415
# 10       THROAT_DISCOMFORT    0.029118
# 9      ALCOHOL_CONSUMPTION    0.020459
# 4            MENTAL_STRESS    0.009749
# 8          BREATHING_ISSUE    0.000000
# 15           STRESS_IMMUNE    0.000000
# 14  SMOKING_FAMILY_HISTORY    0.000000

# %%
X_Selected=X[Selected_features]

# %%
X_Selected.columns
# Out:
# Index(['AGE', 'GENDER', 'SMOKING', 'FINGER_DISCOLORATION', 'MENTAL_STRESS',
#        'EXPOSURE_TO_POLLUTION', 'LONG_TERM_ILLNESS', 'IMMUNE_WEAKNESS',
#        'BREATHING_ISSUE', 'ALCOHOL_CONSUMPTION', 'THROAT_DISCOMFORT',
#        'OXYGEN_SATURATION', 'CHEST_TIGHTNESS', 'FAMILY_HISTORY',
#        'SMOKING_FAMILY_HISTORY', 'STRESS_IMMUNE', 'PULMONARY_DISEASE_NO',
#        'PULMONARY_DISEASE_YES'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_Selected,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
Ss=StandardScaler()
X_train_scaled=Ss.fit_transform(X_train)
X_test_scaled=Ss.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
models={'Linear Regression':LinearRegression(),
        'Random Forest':RandomForestRegressor(random_state=42),
        'Support Vector Machine':SVR(),
        'Decision Tree':DecisionTreeRegressor()}

# %%
results={}
for name,model in models.items():
  model.fit(X_train_scaled,y_train)
  y_pred=model.predict(X_test_scaled)
  results[name]={'MSE':mean_squared_error(y_test,y_pred),
                 'MAE':mean_absolute_error(y_test,y_pred),
                 'R2':r2_score(y_test,y_pred)}

# %%
print("\nModel Performance:")
for model_name,metrics in results.items():
  print(f"{model_name}:")
  for metric_name,value in metrics.items():
    print(f"{metric_name}:{value:.4f}")
# Out:
# Model Performance:
# Linear Regression:
# MSE:57.9993
# MAE:6.1566
# R2:0.0365
# Random Forest:
# MSE:62.6696
# MAE:6.3372
# R2:-0.0411
# Support Vector Machine:
# MSE:58.8132
# MAE:6.1610
# R2:0.0230
# Decision Tree:
# MSE:126.3382
# MAE:8.9487
# R2:-1.0988
